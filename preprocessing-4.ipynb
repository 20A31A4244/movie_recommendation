# %%
import numpy as np
import pandas as pd

# %%
 data = pd.read_csv("data.csv")

# %%
latest = pd.read_csv("latest.csv")

# %%
data.head()
# Out:
#      director_name     actor_1_name    actor_2_name    actor_3_name  \
# 0    John Lasseter        Tom Hanks       Tim Allen     Don Rickles
# 1     Joe Johnston   Robin Williams   Jonathan Hyde   Kirsten Dunst
# 2    Howard Deutch   Walter Matthau     Jack Lemmon     Ann-Margret
# 3  Forest Whitaker  Whitney Houston  Angela Bassett  Loretta Devine
# 4    Charles Shyer     Steve Martin    Diane Keaton    Martin Short
#
#                      genres                  movie_title  \
# 0   Animation Comedy Family                    toy story
# 1  Adventure Fantasy Family                      jumanji
# 2            Romance Comedy             grumpier old men
# 3      Comedy Drama Romance            waiting to exhale
# 4                    Comedy  father of the bride part ii
#
#                                                 comb
# 0  Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1  Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# ...

# %%
latest.head()
# Out:
#         director_name    actor_1_name            actor_2_name    actor_3_name  \
# 0        Adam Robitel       Lin Shaye           Angus Sampson  Leigh Whannell
# 1    Lauren Wolkstein   Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2          Simon West  Dominic Cooper          Austin Stowell      Gemma Chan
# 3    Warwick Thornton     Bryan Brown               Sam Neill         unknown
# 4  Jaume Collet-Serra     Liam Neeson            Vera Farmiga  Patrick Wilson
#
#                     genres              movie_title  \
# 0  Horror Mystery Thriller  insidious: the last key
# 1           Thriller Drama         the strange ones
# 2          Action Thriller                 stratton
# 3   Drama Western Thriller            sweet country
# 4  Action Thriller Mystery             the commuter
#
#                                                 comb
# 0  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1  Alex Pettyfer James Freedson-Jackson Emily Alt...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39213 entries, 0 to 39212
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   director_name  39213 non-null  object
#  1   actor_1_name   39213 non-null  object
#  2   actor_2_name   39213 non-null  object
#  3   actor_3_name   39213 non-null  object
#  4   genres         39213 non-null  object
#  5   movie_title    39213 non-null  object
#  6   comb           39213 non-null  object
# dtypes: object(7)
# memory usage: 2.1+ MB

# %%
main_data = data.append(latest,ignore_index=True)

# %%
main_data
# Out:
#          director_name     actor_1_name     actor_2_name      actor_3_name  \
# 0        John Lasseter        Tom Hanks        Tim Allen       Don Rickles
# 1         Joe Johnston   Robin Williams    Jonathan Hyde     Kirsten Dunst
# 2        Howard Deutch   Walter Matthau      Jack Lemmon       Ann-Margret
# 3      Forest Whitaker  Whitney Houston   Angela Bassett    Loretta Devine
# 4        Charles Shyer     Steve Martin     Diane Keaton      Martin Short
# ...                ...              ...              ...               ...
# 40602     Kasi Lemmons      Naomi Ackie    Stanley Tucci    Ashton Sanders
# 40603     Scott Cooper   Christian Bale    Harry Melling  Gillian Anderson
# 40604     Sarah Polley      Rooney Mara       Claire Foy    Jessie Buckley
# 40605     Marc Forster        Tom Hanks  Mariana Treviño     Rachel Keller
# 40606       Mary Nighy    Anna Kendrick  Kaniehtiio Horn   Charlie Carrick
#
#                               genres  \
# ...

# %%
main_data.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
main_data.duplicated(['movie_title']).sum()
# Out:
# 3100

# %%
main_data.drop_duplicates(subset=['movie_title'],ignore_index=True,keep='last',inplace=True)

# %%
main_data.to_csv("main_data.csv",index=False)

# %%
main_data.shape
# Out:
# (37507, 7)
